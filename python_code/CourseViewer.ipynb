# %%
import networkx as nx
import netwulf as nw
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
courses = pd.read_csv('UpdatedCourses.csv', index_col=0)

# %%
department_list = sorted(list(set(courses.Institut)))

colour_list = ['#E74C3C', '#8E44AD', '#3498DB', '#2ECC71', '#F39C12', '#F1C40F', '#F5B7B1', '#5D6D7E', 
               '#AED6F1','#F5B7B1', '#FCF3CF', '#DCB9ED', '#8F2323', '#8F6A23', '#4F8F23', '#23628F', 
               '#6B238F', '#AED6F1','#A3E4D7']

department_to_colour_dict = {department: colour for department, colour in zip(department_list, colour_list)}

# %%
all_ids = set(courses['Kursus id'])

# %%
SPECIAL_CASE_COURSES = {'02312', '02314', '62531', '62532'}

# %%
class Course:


    def __init__(self, series):
        self.course_id = series['Kursus id']
        self.danish_title = series['Dansk titel']
        self.english_title = series['Engelsk titel']
        self.points = float(series['Point( ECTS )'])
        self.course_type = set(series['Kursustype'].split(','))
        self.location = series['Undervisningens placering']
        if series['Anbefalede forudsætninger'] is not np.nan:
            self.prerequisites = list(ele for ele in set(series['Anbefalede forudsætninger'].split(',')) if not ele == self.course_id)
        else:
            self.prerequisites = []
        self.ins = []
        self.outs = []
        self.responsible = series['Kursusansvarlig']
        self.department = series['Institut']
        self.link = series['Link']
        self.programmes = {program: kind for program, kind in series[10:].items()}
        self.level = None if not self.course_id in SPECIAL_CASE_COURSES else 0

# %%
class CourseList:

    def __init__(self, catalogue={}, courses=set(), N=0):

        if isinstance(catalogue, pd.DataFrame):
            self.catalogue = {}
            self.courses = set()
            self.N = 0
            self.create_course_list_from_dict(catalogue)
        else:
            self.catalogue = catalogue
            self.courses = courses
            self.N = N
            assert len(courses) == N

    def add_course(self, series):
        if series['Kursus id'] not in self.courses:
            self.N += 1
            self.courses.add(series['Kursus id'])
        self.catalogue[series['Kursus id']] = Course(series)

    def add_course_connections(self):
        for course in self.catalogue.values():
            if course.prerequisites is not None and course.prerequisites != 'Unknown':
                for prerequisite in course.prerequisites:
                    if prerequisite in self.courses:
                        course.ins.append(self.catalogue[prerequisite])
                        self.catalogue[prerequisite].outs.append(course)

    def create_course_list_from_dict(self, courses_df):
        for i in range(len(courses_df)):
            self.add_course(courses_df.loc[i])
        self.add_course_connections()

    def lookup(self, course_id):
        return self.catalogue[course_id]

    def assign_levels(self):
        for course in self.catalogue.values():
            #print(course.course_id, course.danish_title)
            self._assign_levels(course, None)

    def _assign_levels(self, course, prev):
        if course.level is not None:
            #print('\t   Already visited')
            return

        loop = False
        max_level = 0
        for prerequisite_course in course.ins:
            if prerequisite_course.course_id == prev:
                loop = True
                continue
            #print('\t', prerequisite_course.course_id, prerequisite_course.danish_title)
            if not self._assign_levels(prerequisite_course, course.course_id):
                max_level = max((max_level, prerequisite_course.level + 1))
        course.level = max_level

        if loop:
            return True
    
    def reset_levels(self):
        for course in self.catalogue.values():
            if not course.course_id in SPECIAL_CASE_COURSES:
                course.level = None
    
    def select_by_department(self, department):
        department_catalogue = {}
        courses = set()
        for course_id, course in self.catalogue.items():
            if course.department == department:
                department_catalogue[course_id] = course
                courses.add(course.course_id)
                for prereq in course.ins:
                    self._select_prerequisites(prereq, department_catalogue, courses)
                    
        return CourseList(department_catalogue, courses, len(courses))
    
    def select_by_program(self, program):
        raise('Not implemented yet')
    
    def _select_prerequisites(self, course, catalogue, courses):
        if course.course_id in courses:
            return
        catalogue[course.course_id] = course
        courses.add(course.course_id)
        for prereq in course.ins:
            self._select_prerequisites(prereq, catalogue, courses)
    
    def graph(self):
        
        G = nx.DiGraph()

        # Add nodes
        for course in self.catalogue.values():
            #print(courses['Point( ECTS )'][i])
            G.add_node(course.course_id, 
                       name = course.danish_title,
                       department = course.department,
                       size = max(float(course.points), 1),
                       responsible = course.responsible,
                       group=department_to_colour_dict[course.department])

        # Add edges
        for course in self.catalogue.values():    
            for prereq in course.ins:
                G.add_edge(prereq.course_id, course.course_id)
        
        return G

# %%
cl = CourseList(courses)
cl.assign_levels()

# %%
G = cl.graph()

# %%
network_G, _ = nw.visualize(G, plot_in_cell_below=False)

# %%
cl2 = cl.select_by_department(department_list[2])
G = cl2.graph()
network_G, _ = nw.visualize(G, plot_in_cell_below=False)

# %%
len(cl2.catalogue)
# Out:
# 112

# %%
department_list
# Out:
# ['01 Institut for Matematik og Computer Science',
#  '10 Institut for Fysik',
#  '12 Institut for Vand og Miljøteknologi',
#  '22 Institut for Sundhedsteknologi',
#  '23 Fødevareinstituttet',
#  '25 Institut for Akvatiske Ressourcer',
#  '26 Institut for Kemi',
#  '27 Institut for Bioteknologi og Biomedicin',
#  '28 Institut for Kemiteknik',
#  '29 DTU Biosustain',
#  '30 Institut for Rumforskning og -teknologi',
#  '34 Institut for Fotonik',
#  '41 Institut for Mekanisk Teknologi',
#  '42 Institut for Teknologi, Ledelse og Økonomi',
#  '46 Institut for Vindenergi',
#  '47 Institut for Energikonvertering- og lagring',
#  '56 DTU Nanolab',
#  '62 Institut for Ingeniørteknologi og -didaktik',
#  '88 Andre kurser']

# %%
levels_dict = defaultdict(lambda: [])
for course in cl.catalogue.values():
    levels_dict[course.level].append(course)

# %%
levels_dict
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {0: [<__main__.Course at 0x22ca3f4f430>,
#               <__main__.Course at 0x22ca2f1c640>,
#               <__main__.Course at 0x22ca2f1ceb0>,
#               <__main__.Course at 0x22ca2f1caf0>,
#               <__main__.Course at 0x22ca2f1cc40>,
#               <__main__.Course at 0x22ca2f1cf40>,
#               <__main__.Course at 0x22ca2f1cd00>,
#               <__main__.Course at 0x22ca2e5b220>,
#               <__main__.Course at 0x22ca2e5b7f0>,
#               <__main__.Course at 0x22ca2e5b6a0>,
#               <__main__.Course at 0x22ca2e5b5e0>,
#               <__main__.Course at 0x22ca2f39c40>,
#               <__main__.Course at 0x22ca2f39dc0>,
#               <__main__.Course at 0x22ca2f39820>,
#               <__main__.Course at 0x22ca2f1ccd0>,
#               <__main__.Course at 0x22ca2e718e0>,
#               <__main__.Course at 0x22ca2d1f880>,
#               <__main__.Course at 0x22ca2d1f5e0>,
#               <__main__.Course at 0x22ca2d1fc70>,
#               <__main__.Course at 0x22ca2d54c10>,
#               <__main__.Course at 0x22ca2f56bb0>,
#               <__main__.Course at 0x22ca2f56640>,
#               <__main__.Course at 0x22ca2f566d0>,
#               <__main__.Course at 0x22ca2f56e20>,
#               <__main__.Course at 0x22ca2ce96d0>,
#               <__main__.Course at 0x22cd1318550>,
#               <__main__.Course at 0x22ca407f6d0>,
#               <__main__.Course at 0x22ca2efe220>,
#               <__main__.Course at 0x22ca2ce9220>,
#               <__main__.Course at 0x22ca2d39dc0>,
#               <__main__.Course at 0x22ca2d39cd0>,
#               <__main__.Course at 0x22ca2d395b0>,
#               <__main__.Course at 0x22ca2d399a0>,
#               <__main__.Course at 0x22ca2d39b50>,
#               <__main__.Course at 0x22ca2d39610>,
#               <__main__.Course at 0x22ca2d39d30>,
#               <__main__.Course at 0x22ca2d39ac0>,
#               <__main__.Course at 0x22ca2d398e0>,
#               <__main__.Course at 0x22ca2d394c0>,
#               <__main__.Course at 0x22ca2d391c0>,
#               <__main__.Course at 0x22ca2d39520>,
#               <__main__.Course at 0x22ca2d39eb0>,
#               <__main__.Course at 0x22ca2d39130>,
#               <__main__.Course at 0x22ca2d39df0>,
#               <__main__.Course at 0x22ca2d39e50>,
#               <__main__.Course at 0x22ca2d392b0>,
#               <__main__.Course at 0x22ca2d39040>,
#               <__main__.Course at 0x22ca2c76160>,
#               <__main__.Course at 0x22ca2c76df0>,
#               <__main__.Course at 0x22ca2c76070>,
#               <__main__.Course at 0x22ca2c76520>,
#               <__main__.Course at 0x22ca2e8c970>,
#               <__main__.Course at 0x22ca2e8cfa0>,
#               <__main__.Course at 0x22ca2c71640>,
#               <__main__.Course at 0x22ca2c71eb0>,
#               <__main__.Course at 0x22ca2c714f0>,
#               <__main__.Course at 0x22ca3f6aa60>,
#               <__main__.Course at 0x22ca3f6a340>,
#               <__main__.Course at 0x22ca3f6a670>,
#               <__main__.Course at 0x22ca3f6a6d0>,
#               <__main__.Course at 0x22ca3fbb130>,
#               <__main__.Course at 0x22ca2d048e0>,
#               <__main__.Course at 0x22ca2d04c40>,
#               <__main__.Course at 0x22ca2d04790>,
#               <__main__.Course at 0x22ca2d04c10>,
#               <__main__.Course at 0x22ca2d04220>,
#               <__main__.Course at 0x22ca2e8cc70>,
#               <__main__.Course at 0x22ca2efe070>,
#               <__main__.Course at 0x22ca2d04340>,
#               <__main__.Course at 0x22ca2d044c0>,
#               <__main__.Course at 0x22ca2d04280>,
#               <__main__.Course at 0x22ca2d04c70>,
#               <__main__.Course at 0x22ca2d04370>,
#               <__main__.Course at 0x22ca2d04430>,
#               <__main__.Course at 0x22ca2d04670>,
#               <__main__.Course at 0x22ca2d04310>,
#               <__main__.Course at 0x22ca433b880>,
#               <__main__.Course at 0x22ca433b940>,
#               <__main__.Course at 0x22ca433b910>,
#               <__main__.Course at 0x22ca433b7c0>,
#               <__main__.Course at 0x22ca433b9d0>,
#               <__main__.Course at 0x22ca433b790>,
#               <__main__.Course at 0x22ca433b8e0>,
#               <__main__.Course at 0x22ca433b820>,
#               <__main__.Course at 0x22ca433b8b0>,
#               <__main__.Course at 0x22ca433b7f0>,
#               <__main__.Course at 0x22ca433b850>,
#               <__main__.Course at 0x22ca433b9a0>,
#               <__main__.Course at 0x22ca433ba00>,
#               <__main__.Course at 0x22ca433ba30>,
#               <__main__.Course at 0x22ca433b730>,
#               <__main__.Course at 0x22ca433ba60>,
#               <__main__.Course at 0x22ca433bac0>,
#               <__main__.Course at 0x22ca433ba90>,
#               <__main__.Course at 0x22ca433baf0>,
#               <__main__.Course at 0x22ca433bbb0>,
#               <__main__.Course at 0x22ca433bbe0>,
#               <__main__.Course at 0x22ca433bb80>,
#               <__main__.Course at 0x22ca433bb20>,
#               <__main__.Course at 0x22ca433bca0>,
#               <__main__.Course at 0x22ca433bd00>,
#               <__main__.Course at 0x22ca2ea96d0>,
#               <__main__.Course at 0x22ca433bdc0>,
#               <__main__.Course at 0x22ca433bdf0>,
#               <__main__.Course at 0x22ca433bfa0>,
#               <__main__.Course at 0x22ca433be50>,
#               <__main__.Course at 0x22ca433beb0>,
#               <__main__.Course at 0x22ca433be20>,
#               <__main__.Course at 0x22ca2f68280>,
#               <__main__.Course at 0x22ca2f68e50>,
#               <__main__.Course at 0x22ca2f68b20>,
#               <__main__.Course at 0x22ca2f68370>,
#               <__main__.Course at 0x22ca2f68dc0>,
#               <__main__.Course at 0x22ca2f688e0>,
#               <__main__.Course at 0x22ca2f68a60>,
#               <__main__.Course at 0x22ca2f68790>,
#               <__main__.Course at 0x22ca2f68d60>,
#               <__main__.Course at 0x22ca2f687f0>,
#               <__main__.Course at 0x22ca2ccec40>,
#               <__main__.Course at 0x22ca2cceb80>,
#               <__main__.Course at 0x22ca2cce550>,
#               <__main__.Course at 0x22ca2ccee80>,
#               <__main__.Course at 0x22ca2ccedf0>,
#               <__main__.Course at 0x22ca2cce520>,
#               <__main__.Course at 0x22ca2cced30>,
#               <__main__.Course at 0x22ca2cce760>,
#               <__main__.Course at 0x22ca2cceee0>,
#               <__main__.Course at 0x22ca2cce430>,
#               <__main__.Course at 0x22ca2cce2e0>,
#               <__main__.Course at 0x22ca2cce220>,
#               <__main__.Course at 0x22cd1323040>,
#               <__main__.Course at 0x22cd1323490>,
#               <__main__.Course at 0x22cd13235b0>,
#               <__main__.Course at 0x22cd1323ac0>,
#               <__main__.Course at 0x22cd1323a00>,
#               <__main__.Course at 0x22cd1323a60>,
#               <__main__.Course at 0x22cd1323880>,
#               <__main__.Course at 0x22cd1323910>,
#               <__main__.Course at 0x22cd1323820>,
#               <__main__.Course at 0x22cd1323b20>,
#               <__main__.Course at 0x22ca44db0d0>,
#               <__main__.Course at 0x22ca44db160>,
#               <__main__.Course at 0x22ca44db070>,
#               <__main__.Course at 0x22ca44db280>,
#               <__main__.Course at 0x22ca44db0a0>,
#               <__main__.Course at 0x22ca44db040>,
#               <__main__.Course at 0x22ca44db130>,
#               <__main__.Course at 0x22ca44db100>,
#               <__main__.Course at 0x22ca44db190>,
#               <__main__.Course at 0x22ca44db1c0>,
#               <__main__.Course at 0x22ca44db310>,
#               <__main__.Course at 0x22ca44db610>,
#               <__main__.Course at 0x22ca44db4c0>,
#               <__main__.Course at 0x22ca44db550>,
#               <__main__.Course at 0x22ca44db400>,
#               <__main__.Course at 0x22ca44dba90>,
#               <__main__.Course at 0x22ca44dbbb0>,
#               <__main__.Course at 0x22ca44db940>,
#               <__main__.Course at 0x22ca44dbc40>,
#               <__main__.Course at 0x22ca44db7f0>,
#               <__main__.Course at 0x22ca44dbac0>,
#               <__main__.Course at 0x22ca44dbc70>,
#               <__main__.Course at 0x22ca44db820>,
#               <__main__.Course at 0x22ca44dba30>,
#               <__main__.Course at 0x22ca44dbd90>,
#               <__main__.Course at 0x22ca44dbdc0>,
#               <__main__.Course at 0x22ca44dbfa0>,
#               <__main__.Course at 0x22ca44dbe50>,
#               <__main__.Course at 0x22ca44dbfd0>,
#               <__main__.Course at 0x22ca44dbf40>,
#               <__main__.Course at 0x22ca44e3130>,
#               <__main__.Course at 0x22ca44e31f0>,
#               <__main__.Course at 0x22ca44e3100>,
#               <__main__.Course at 0x22ca44e3040>,
#               <__main__.Course at 0x22ca44e30a0>,
#               <__main__.Course at 0x22ca44e3250>,
#               <__main__.Course at 0x22ca44e32b0>,
#               <__main__.Course at 0x22ca44e32e0>,
#               <__main__.Course at 0x22ca44e3340>,
#               <__main__.Course at 0x22ca44e34c0>,
#               <__main__.Course at 0x22ca44e3370>,
#               <__main__.Course at 0x22ca44e3400>,
#               <__main__.Course at 0x22ca44e3430>,
#               <__main__.Course at 0x22ca44e33a0>,
#               <__main__.Course at 0x22ca44e33d0>,
#               <__main__.Course at 0x22ca44e3460>,
#               <__main__.Course at 0x22ca44e34f0>,
#               <__main__.Course at 0x22ca44e35b0>,
#               <__main__.Course at 0x22ca44e35e0>,
#               <__main__.Course at 0x22ca44e3610>,
#               <__main__.Course at 0x22ca44e37f0>,
#               <__main__.Course at 0x22ca44e38b0>,
#               <__main__.Course at 0x22ca44e3700>,
#               <__main__.Course at 0x22ca44e3970>,
#               <__main__.Course at 0x22ca44e3a60>,
#               <__main__.Course at 0x22ca44e39a0>,
#               <__main__.Course at 0x22ca44e3910>,
#               <__main__.Course at 0x22ca44e3640>,
#               <__main__.Course at 0x22ca44e3c40>,
#               <__main__.Course at 0x22ca44e3a90>,
#               <__main__.Course at 0x22ca44e3b20>,
#               <__main__.Course at 0x22ca44e39d0>,
#               <__main__.Course at 0x22ca44e3be0>,
#               <__main__.Course at 0x22ca44e3df0>,
#               <__main__.Course at 0x22ca44e3a00>,
#               <__main__.Course at 0x22ca44e3d30>,
#               <__main__.Course at 0x22ca44e3d60>,
#               <__main__.Course at 0x22ca44e3c70>,
#               <__main__.Course at 0x22ca44e3f10>,
#               <__main__.Course at 0x22ca44e3f70>,
#               <__main__.Course at 0x22ca439b1c0>,
#               <__main__.Course at 0x22ca439b040>,
#               <__main__.Course at 0x22ca439b190>,
#               <__main__.Course at 0x22ca439b100>,
#               <__main__.Course at 0x22ca439b130>,
#               <__main__.Course at 0x22ca439b160>,
#               <__main__.Course at 0x22ca439b0d0>,
#               <__main__.Course at 0x22ca439b0a0>,
#               <__main__.Course at 0x22ca439b1f0>,
#               <__main__.Course at 0x22ca439b220>,
#               <__main__.Course at 0x22ca439b250>,
#               <__main__.Course at 0x22ca439b280>,
#               <__main__.Course at 0x22ca439b2b0>,
#               <__main__.Course at 0x22ca439b2e0>,
#               <__main__.Course at 0x22ca439b310>,
#               <__main__.Course at 0x22ca439b340>,
#               <__main__.Course at 0x22ca439b3a0>,
#               <__main__.Course at 0x22ca439b400>,
#               <__main__.Course at 0x22ca439b430>,
#               <__main__.Course at 0x22ca439b5b0>,
#               <__main__.Course at 0x22ca439b640>,
#               <__main__.Course at 0x22ca439b4f0>,
#               <__main__.Course at 0x22ca439b4c0>,
#               <__main__.Course at 0x22ca439b550>,
#               <__main__.Course at 0x22ca439b520>,
#               <__main__.Course at 0x22ca439b6a0>,
#               <__main__.Course at 0x22ca439b490>,
#               <__main__.Course at 0x22ca439b5e0>,
#               <__main__.Course at 0x22ca439b970>,
#               <__main__.Course at 0x22ca439b8b0>,
#               <__main__.Course at 0x22ca439ba30>,
#               <__main__.Course at 0x22ca439ba90>,
#               <__main__.Course at 0x22ca439b8e0>,
#               <__main__.Course at 0x22ca439bb20>,
#               <__main__.Course at 0x22ca439b7f0>,
#               <__main__.Course at 0x22ca439b9d0>,
#               <__main__.Course at 0x22ca439b880>,
#               <__main__.Course at 0x22ca439b910>,
#               <__main__.Course at 0x22ca439bac0>,
#               <__main__.Course at 0x22ca439bb50>,
#               <__main__.Course at 0x22ca439bb80>,
#               <__main__.Course at 0x22ca439bbe0>,
#               <__main__.Course at 0x22ca439bc10>,
#               <__main__.Course at 0x22ca439bc70>,
#               <__main__.Course at 0x22ca439bcd0>,
#               <__main__.Course at 0x22ca439bd00>,
#               <__main__.Course at 0x22ca439be80>,
#               <__main__.Course at 0x22ca439bd30>,
#               <__main__.Course at 0x22ca439bdc0>,
#               <__main__.Course at 0x22ca439bdf0>,
#               <__main__.Course at 0x22ca439bd60>,
#               <__main__.Course at 0x22ca439bd90>,
#               <__main__.Course at 0x22ca439be20>,
#               <__main__.Course at 0x22ca439beb0>,
#               <__main__.Course at 0x22ca439bfd0>,
#               <__main__.Course at 0x22ca439bfa0>,
#               <__main__.Course at 0x22ca439bf70>,
#               <__main__.Course at 0x22ca439bf40>,
#               <__main__.Course at 0x22ca439bee0>,
#               <__main__.Course at 0x22ca439bf10>,
#               <__main__.Course at 0x22ca43b7190>,
#               <__main__.Course at 0x22ca43b7160>,
#               <__main__.Course at 0x22ca43b70d0>,
#               <__main__.Course at 0x22ca43b7100>,
#               <__main__.Course at 0x22ca43b7130>,
#               <__main__.Course at 0x22ca43b72b0>,
#               <__main__.Course at 0x22ca43b7250>,
#               <__main__.Course at 0x22ca43b7460>,
#               <__main__.Course at 0x22ca43b7580>,
#               <__main__.Course at 0x22ca43b75b0>,
#               <__main__.Course at 0x22ca43b7640>,
#               <__main__.Course at 0x22ca43b7af0>,
#               <__main__.Course at 0x22ca43b7a90>,
#               <__main__.Course at 0x22ca43b7c70>,
#               <__main__.Course at 0x22ca43b7be0>,
#               <__main__.Course at 0x22ca43b79d0>,
#               <__main__.Course at 0x22ca43b7dc0>,
#               <__main__.Course at 0x22ca43b7c10>,
#               <__main__.Course at 0x22ca43b7cd0>,
#               <__main__.Course at 0x22ca43b7d60>,
#               <__main__.Course at 0x22ca43b7df0>,
#               <__main__.Course at 0x22ca43b7f70>,
#               <__main__.Course at 0x22ca43b7fd0>,
#               <__main__.Course at 0x22ca43b7f10>,
#               <__main__.Course at 0x22ca43d22b0>,
#               <__main__.Course at 0x22ca43d2160>,
#               <__main__.Course at 0x22ca43d24f0>,
#               <__main__.Course at 0x22ca43d2100>,
#               <__main__.Course at 0x22ca43d2910>,
#               <__main__.Course at 0x22ca43d29d0>,
#               <__main__.Course at 0x22ca43d2a30>,
#               <__main__.Course at 0x22ca43d2a90>,
#               <__main__.Course at 0x22ca43d2400>,
#               <__main__.Course at 0x22ca43d2610>,
#               <__main__.Course at 0x22ca43d2760>,
#               <__main__.Course at 0x22ca43d2b80>,
#               <__main__.Course at 0x22ca43d2be0>,
#               <__main__.Course at 0x22ca43d26d0>,
#               <__main__.Course at 0x22ca43d2640>,
#               <__main__.Course at 0x22ca43d2af0>,
#               <__main__.Course at 0x22ca43d2b20>,
#               <__main__.Course at 0x22ca43d2d90>,
#               <__main__.Course at 0x22ca43d2e80>,
#               <__main__.Course at 0x22ca43e9100>,
#               <__main__.Course at 0x22ca43e93d0>,
#               <__main__.Course at 0x22ca43e9790>,
#               <__main__.Course at 0x22ca43e9370>,
#               <__main__.Course at 0x22ca43e98b0>,
#               <__main__.Course at 0x22ca43e9880>,
#               <__main__.Course at 0x22ca43e99a0>,
#               <__main__.Course at 0x22ca43e9a30>,
#               <__main__.Course at 0x22ca43e9be0>,
#               <__main__.Course at 0x22ca43e9730>,
#               <__main__.Course at 0x22ca43e9b20>,
#               <__main__.Course at 0x22ca43e9b50>,
#               <__main__.Course at 0x22ca43e9cd0>,
#               <__main__.Course at 0x22ca43e9a60>,
#               <__main__.Course at 0x22ca43e9c10>,
#               <__main__.Course at 0x22ca43e9c40>,
#               <__main__.Course at 0x22ca43e9af0>,
#               <__main__.Course at 0x22ca43e9b80>,
#               <__main__.Course at 0x22ca43e9c70>,
#               <__main__.Course at 0x22ca43e9d00>,
#               <__main__.Course at 0x22ca43e9d30>,
#               <__main__.Course at 0x22ca43e9d60>,
#               <__main__.Course at 0x22ca43e9d90>,
#               <__main__.Course at 0x22ca43e9dc0>,
#               <__main__.Course at 0x22ca43e9df0>,
#               <__main__.Course at 0x22ca43e9e20>,
#               <__main__.Course at 0x22ca43e9e50>,
#               <__main__.Course at 0x22ca43e9e80>,
#               <__main__.Course at 0x22ca43e9eb0>,
#               <__main__.Course at 0x22ca43e9fa0>,
#               <__main__.Course at 0x22ca43e9ee0>,
#               <__main__.Course at 0x22ca44030d0>,
#               <__main__.Course at 0x22ca4403100>,
#               <__main__.Course at 0x22ca4403070>,
#               <__main__.Course at 0x22ca4403400>,
#               <__main__.Course at 0x22ca44031f0>,
#               <__main__.Course at 0x22ca4403220>,
#               <__main__.Course at 0x22ca4403640>,
#               <__main__.Course at 0x22ca4403cd0>,
#               <__main__.Course at 0x22ca4403d60>,
#               <__main__.Course at 0x22ca4403dc0>,
#               <__main__.Course at 0x22ca4403fa0>,
#               <__main__.Course at 0x22ca441e100>,
#               <__main__.Course at 0x22ca441e040>,
#               <__main__.Course at 0x22ca441e2b0>,
#               <__main__.Course at 0x22ca441e2e0>,
#               <__main__.Course at 0x22ca441e3a0>,
#               <__main__.Course at 0x22ca441e220>,
#               <__main__.Course at 0x22ca441e610>,
#               <__main__.Course at 0x22ca441e550>,
#               <__main__.Course at 0x22ca441e580>,
#               <__main__.Course at 0x22ca441e7f0>,
#               <__main__.Course at 0x22ca441e820>,
#               <__main__.Course at 0x22ca441e730>,
#               <__main__.Course at 0x22ca441e9d0>,
#               <__main__.Course at 0x22ca441e7c0>,
#               <__main__.Course at 0x22ca441e940>,
#               <__main__.Course at 0x22ca441e970>,
#               <__main__.Course at 0x22ca441ebe0>,
#               <__main__.Course at 0x22ca441ea90>,
#               <__main__.Course at 0x22ca441eb20>,
#               <__main__.Course at 0x22ca441ec10>,
#               <__main__.Course at 0x22ca441ec40>,
#               <__main__.Course at 0x22ca441eeb0>,
#               <__main__.Course at 0x22ca441ef40>,
#               <__main__.Course at 0x22ca441eee0>,
#               <__main__.Course at 0x22ca441edf0>,
#               <__main__.Course at 0x22ca443b250>,
#               <__main__.Course at 0x22ca443b160>,
#               <__main__.Course at 0x22ca443b1f0>,
#               <__main__.Course at 0x22ca443b400>,
#               <__main__.Course at 0x22ca443b070>,
#               <__main__.Course at 0x22ca443b340>,
#               <__main__.Course at 0x22ca443b3a0>,
#               <__main__.Course at 0x22ca443b5b0>,
#               <__main__.Course at 0x22ca443b6d0>,
#               <__main__.Course at 0x22ca443b4c0>,
#               <__main__.Course at 0x22ca443b520>,
#               <__main__.Course at 0x22ca443b670>,
#               <__main__.Course at 0x22ca443b5e0>,
#               <__main__.Course at 0x22ca443b880>,
#               <__main__.Course at 0x22ca443b7c0>,
#               <__main__.Course at 0x22ca443b700>,
#               <__main__.Course at 0x22ca443b820>,
#               <__main__.Course at 0x22ca443b910>,
#               <__main__.Course at 0x22ca443bb50>,
#               <__main__.Course at 0x22ca443b9a0>,
#               <__main__.Course at 0x22ca443bc40>,
#               <__main__.Course at 0x22ca443bd90>,
#               <__main__.Course at 0x22ca443bf70>,
#               <__main__.Course at 0x22ca443bfd0>,
#               <__main__.Course at 0x22ca443be80>,
#               <__main__.Course at 0x22ca44560d0>,
#               <__main__.Course at 0x22ca4456280>,
#               <__main__.Course at 0x22ca4456430>,
#               <__main__.Course at 0x22ca44568b0>,
#               <__main__.Course at 0x22ca4456940>,
#               <__main__.Course at 0x22ca4456a60>,
#               <__main__.Course at 0x22ca4456c70>,
#               <__main__.Course at 0x22ca4456ca0>,
#               <__main__.Course at 0x22ca4456a90>,
#               <__main__.Course at 0x22ca4456b20>,
#               <__main__.Course at 0x22ca4456dc0>,
#               <__main__.Course at 0x22ca44714c0>,
#               <__main__.Course at 0x22ca44712e0>,
#               <__main__.Course at 0x22ca44715e0>,
#               <__main__.Course at 0x22ca4471850>,
#               <__main__.Course at 0x22ca4471790>,
#               <__main__.Course at 0x22ca4471880>,
#               <__main__.Course at 0x22ca44719a0>,
#               <__main__.Course at 0x22ca4471b80>,
#               <__main__.Course at 0x22ca4471ca0>,
#               <__main__.Course at 0x22ca4471cd0>,
#               <__main__.Course at 0x22ca4471d30>,
#               <__main__.Course at 0x22ca4471f70>,
#               <__main__.Course at 0x22ca4471e20>,
#               <__main__.Course at 0x22ca44f0040>,
#               <__main__.Course at 0x22ca44f0280>,
#               <__main__.Course at 0x22ca44f0490>,
#               <__main__.Course at 0x22ca44f0100>,
#               <__main__.Course at 0x22ca44f01c0>,
#               <__main__.Course at 0x22ca44f0130>,
#               <__main__.Course at 0x22ca44f0340>,
#               <__main__.Course at 0x22ca44f04c0>,
#               <__main__.Course at 0x22ca44f04f0>,
#               <__main__.Course at 0x22ca44f0520>,
#               <__main__.Course at 0x22ca44f05e0>,
#               <__main__.Course at 0x22ca44f0640>,
#               <__main__.Course at 0x22ca44f08e0>,
#               <__main__.Course at 0x22ca44f0880>,
#               <__main__.Course at 0x22ca44f0a60>,
#               <__main__.Course at 0x22ca44f0910>,
#               <__main__.Course at 0x22ca44f09a0>,
#               <__main__.Course at 0x22ca44f0bb0>,
#               <__main__.Course at 0x22ca44f0cd0>,
#               <__main__.Course at 0x22ca44f0e50>,
#               <__main__.Course at 0x22ca44f0be0>,
#               <__main__.Course at 0x22ca44f0d90>,
#               <__main__.Course at 0x22ca44f0dc0>,
#               <__main__.Course at 0x22ca44f0f40>,
#               <__main__.Course at 0x22ca44f0c70>,
#               <__main__.Course at 0x22ca44f0eb0>,
#               <__main__.Course at 0x22ca44f0fd0>,
#               <__main__.Course at 0x22ca44f0f70>,
#               <__main__.Course at 0x22ca44f0ee0>,
#               <__main__.Course at 0x22ca44f0d00>,
#               <__main__.Course at 0x22ca44f0df0>,
#               <__main__.Course at 0x22ca450d130>,
#               <__main__.Course at 0x22ca450d160>,
#               <__main__.Course at 0x22ca450d0a0>,
#               <__main__.Course at 0x22ca450d0d0>,
#               <__main__.Course at 0x22ca450d100>,
#               <__main__.Course at 0x22ca450d070>,
#               <__main__.Course at 0x22ca450d040>,
#               <__main__.Course at 0x22ca450d190>,
#               <__main__.Course at 0x22ca450d1c0>,
#               <__main__.Course at 0x22ca450d220>,
#               <__main__.Course at 0x22ca450d250>,
#               <__main__.Course at 0x22ca450d280>,
#               <__main__.Course at 0x22ca450d430>,
#               <__main__.Course at 0x22ca450d2e0>,
#               <__main__.Course at 0x22ca450d370>,
#               <__main__.Course at 0x22ca450d490>,
#               <__main__.Course at 0x22ca450d3d0>,
#               <__main__.Course at 0x22ca450d670>,
#               <__main__.Course at 0x22ca450d5b0>,
#               <__main__.Course at 0x22ca450d580>,
#               <__main__.Course at 0x22ca450da60>,
#               <__main__.Course at 0x22ca450dac0>,
#               <__main__.Course at 0x22ca450d7c0>,
#               <__main__.Course at 0x22ca450d850>,
#               <__main__.Course at 0x22ca450daf0>,
#               <__main__.Course at 0x22ca450d8e0>,
#               <__main__.Course at 0x22ca450dca0>,
#               <__main__.Course at 0x22ca450dd30>,
#               <__main__.Course at 0x22ca450dbe0>,
#               <__main__.Course at 0x22ca450dbb0>,
#               <__main__.Course at 0x22ca450dc40>,
#               <__main__.Course at 0x22ca450dc10>,
#               <__main__.Course at 0x22ca450db20>,
#               <__main__.Course at 0x22ca450dcd0>,
#               <__main__.Course at 0x22ca450ddf0>,
#               <__main__.Course at 0x22ca450de50>,
#               <__main__.Course at 0x22ca450df70>,
#               <__main__.Course at 0x22ca450dee0>,
#               <__main__.Course at 0x22ca450deb0>,
#               <__main__.Course at 0x22ca450df40>,
#               <__main__.Course at 0x22ca450de80>,
#               <__main__.Course at 0x22ca4529040>,
#               <__main__.Course at 0x22ca4529160>,
#               <__main__.Course at 0x22ca45290d0>,
#               <__main__.Course at 0x22ca4529250>,
#               <__main__.Course at 0x22ca4529100>,
#               <__main__.Course at 0x22ca4529070>,
#               <__main__.Course at 0x22ca45291c0>,
#               <__main__.Course at 0x22ca4529130>,
#               <__main__.Course at 0x22ca45290a0>,
#               <__main__.Course at 0x22ca45291f0>,
#               <__main__.Course at 0x22ca4529280>,
#               <__main__.Course at 0x22ca45292b0>,
#               <__main__.Course at 0x22ca45292e0>,
#               <__main__.Course at 0x22ca4529310>,
#               <__main__.Course at 0x22ca4529340>,
#               <__main__.Course at 0x22ca4529370>,
#               <__main__.Course at 0x22ca45293a0>,
#               <__main__.Course at 0x22ca45293d0>,
#               <__main__.Course at 0x22ca4529400>,
#               <__main__.Course at 0x22ca4529430>,
#               <__main__.Course at 0x22ca4529490>,
#               <__main__.Course at 0x22ca45294c0>,
#               <__main__.Course at 0x22ca45294f0>,
#               <__main__.Course at 0x22ca45295b0>,
#               <__main__.Course at 0x22ca4529730>,
#               <__main__.Course at 0x22ca4529790>,
#               <__main__.Course at 0x22ca45299d0>,
#               <__main__.Course at 0x22ca4529bb0>,
#               <__main__.Course at 0x22ca4529820>,
#               <__main__.Course at 0x22ca4529970>,
#               <__main__.Course at 0x22ca4529d90>,
#               <__main__.Course at 0x22ca4529df0>,
#               <__main__.Course at 0x22ca4529ac0>,
#               <__main__.Course at 0x22ca4529ee0>,
#               <__main__.Course at 0x22ca4529b50>,
#               <__main__.Course at 0x22ca4529f70>,
#               <__main__.Course at 0x22ca4529fd0>,
#               <__main__.Course at 0x22ca4529e80>,
#               <__main__.Course at 0x22ca45421c0>,
#               <__main__.Course at 0x22ca4542040>,
#               <__main__.Course at 0x22ca4542190>,
#               <__main__.Course at 0x22ca45422b0>,
#               <__main__.Course at 0x22ca4542100>,
#               <__main__.Course at 0x22ca4542130>,
#               <__main__.Course at 0x22ca4542160>,
#               <__main__.Course at 0x22ca45420d0>,
#               <__main__.Course at 0x22ca45420a0>,
#               <__main__.Course at 0x22ca45421f0>,
#               <__main__.Course at 0x22ca45422e0>,
#               <__main__.Course at 0x22ca4542310>,
#               <__main__.Course at 0x22ca4542400>,
#               <__main__.Course at 0x22ca4542430>,
#               <__main__.Course at 0x22ca45424c0>,
#               <__main__.Course at 0x22ca4542700>,
#               <__main__.Course at 0x22ca4542880>,
#               <__main__.Course at 0x22ca4542a90>,
#               <__main__.Course at 0x22ca4542b20>,
#               <__main__.Course at 0x22ca4542a30>,
#               <__main__.Course at 0x22ca4542a00>,
#               <__main__.Course at 0x22ca45427f0>,
#               <__main__.Course at 0x22ca4542ac0>,
#               <__main__.Course at 0x22ca4542b50>,
#               <__main__.Course at 0x22ca4542bb0>,
#               <__main__.Course at 0x22ca4542be0>,
#               <__main__.Course at 0x22ca4542c10>,
#               <__main__.Course at 0x22ca4542c40>,
#               <__main__.Course at 0x22ca4542c70>,
#               <__main__.Course at 0x22ca4542ca0>,
#               <__main__.Course at 0x22ca4542cd0>,
#               <__main__.Course at 0x22ca4542d00>,
#               <__main__.Course at 0x22ca4542d30>,
#               <__main__.Course at 0x22ca4542d60>,
#               <__main__.Course at 0x22ca4542dc0>,
#               <__main__.Course at 0x22ca4542e20>,
#               <__main__.Course at 0x22ca4542eb0>,
#               <__main__.Course at 0x22ca4542fd0>,
#               <__main__.Course at 0x22ca4542fa0>,
#               <__main__.Course at 0x22ca4542f70>,
#               <__main__.Course at 0x22ca4542ee0>,
#               <__main__.Course at 0x22ca4542f10>,
#               <__main__.Course at 0x22ca455f070>,
#               <__main__.Course at 0x22ca455f040>,
#               <__main__.Course at 0x22ca455f1c0>,
#               <__main__.Course at 0x22ca455f190>,
#               <__main__.Course at 0x22ca455f130>,
#               <__main__.Course at 0x22ca455f0d0>,
#               <__main__.Course at 0x22ca455f0a0>,
#               <__main__.Course at 0x22ca455f220>,
#               <__main__.Course at 0x22ca455f3a0>,
#               <__main__.Course at 0x22ca455f310>,
#               <__main__.Course at 0x22ca455f280>,
#               <__main__.Course at 0x22ca455f340>,
#               <__main__.Course at 0x22ca455f520>,
#               <__main__.Course at 0x22ca455f3d0>,
#               <__main__.Course at 0x22ca455f460>,
#               <__main__.Course at 0x22ca455f490>,
#               <__main__.Course at 0x22ca455f400>,
#               <__main__.Course at 0x22ca455f430>,
#               <__main__.Course at 0x22ca455f580>,
#               <__main__.Course at 0x22ca455f5b0>,
#               <__main__.Course at 0x22ca455f5e0>,
#               <__main__.Course at 0x22ca455f670>,
#               <__main__.Course at 0x22ca455f6a0>,
#               <__main__.Course at 0x22ca455f6d0>,
#               <__main__.Course at 0x22ca455f850>,
#               <__main__.Course at 0x22ca455f790>,
#               <__main__.Course at 0x22ca455f7c0>,
#               <__main__.Course at 0x22ca455f730>,
#               <__main__.Course at 0x22ca455f760>,
#               <__main__.Course at 0x22ca455f880>,
#               <__main__.Course at 0x22ca455f8b0>,
#               <__main__.Course at 0x22ca455f8e0>,
#               <__main__.Course at 0x22ca455f970>,
#               <__main__.Course at 0x22ca455f9a0>,
#               <__main__.Course at 0x22ca455f9d0>,
#               <__main__.Course at 0x22ca455fa00>,
#               <__main__.Course at 0x22ca455fb80>,
#               <__main__.Course at 0x22ca455fa30>,
#               <__main__.Course at 0x22ca455fa90>,
#               <__main__.Course at 0x22ca455fb20>,
#               <__main__.Course at 0x22ca455fd60>,
#               <__main__.Course at 0x22ca455fc10>,
#               <__main__.Course at 0x22ca455fca0>,
#               <__main__.Course at 0x22ca455fe20>,
#               <__main__.Course at 0x22ca455fe80>,
#               <__main__.Course at 0x22ca455fdc0>,
#               <__main__.Course at 0x22ca455ff40>,
#               <__main__.Course at 0x22ca455ff10>,
#               <__main__.Course at 0x22ca457c370>,
#               <__main__.Course at 0x22ca457c610>,
#               <__main__.Course at 0x22ca457c700>,
#               <__main__.Course at 0x22ca457c940>,
#               <__main__.Course at 0x22ca457c9a0>,
#               <__main__.Course at 0x22ca457c8b0>,
#               <__main__.Course at 0x22ca457c8e0>,
#               <__main__.Course at 0x22ca457cb50>,
#               <__main__.Course at 0x22ca457c7c0>,
#               <__main__.Course at 0x22ca457ca90>,
#               <__main__.Course at 0x22ca457cac0>,
#               <__main__.Course at 0x22ca457c9d0>,
#               <__main__.Course at 0x22ca457caf0>,
#               <__main__.Course at 0x22ca457cd60>,
#               <__main__.Course at 0x22ca457cca0>,
#               <__main__.Course at 0x22ca457ce20>,
#               <__main__.Course at 0x22ca457ccd0>,
#               <__main__.Course at 0x22ca457cee0>,
#               <__main__.Course at 0x22ca457ce50>,
#               <__main__.Course at 0x22ca457cc40>,
#               <__main__.Course at 0x22ca457cfd0>,
#               <__main__.Course at 0x22ca457cf10>,
#               <__main__.Course at 0x22ca457ce80>,
#               <__main__.Course at 0x22ca457cf40>,
#               <__main__.Course at 0x22ca45941c0>,
#               <__main__.Course at 0x22ca4594100>,
#               <__main__.Course at 0x22ca45940a0>,
#               <__main__.Course at 0x22ca4594220>,
#               <__main__.Course at 0x22ca4594400>,
#               <__main__.Course at 0x22ca4594280>,
#               <__main__.Course at 0x22ca4594310>,
#               <__main__.Course at 0x22ca45943a0>,
#               <__main__.Course at 0x22ca4594640>,
#               <__main__.Course at 0x22ca4594490>,
#               <__main__.Course at 0x22ca4594550>,
#               <__main__.Course at 0x22ca45946a0>,
#               <__main__.Course at 0x22ca4594910>,
#               <__main__.Course at 0x22ca4594790>,
#               <__main__.Course at 0x22ca4594b80>,
#               <__main__.Course at 0x22ca4594be0>,
#               <__main__.Course at 0x22ca4594df0>,
#               <__main__.Course at 0x22ca4594ac0>,
#               <__main__.Course at 0x22ca4594e50>,
#               <__main__.Course at 0x22ca4594d00>,
#               <__main__.Course at 0x22ca4594fa0>,
#               <__main__.Course at 0x22ca45ad0d0>,
#               <__main__.Course at 0x22ca45ad040>,
#               <__main__.Course at 0x22ca45ad340>,
#               <__main__.Course at 0x22ca45ad3a0>,
#               <__main__.Course at 0x22ca45ad1c0>,
#               <__main__.Course at 0x22ca45ad070>,
#               <__main__.Course at 0x22ca45ad400>,
#               <__main__.Course at 0x22ca45ad580>,
#               <__main__.Course at 0x22ca45ad5e0>,
#               <__main__.Course at 0x22ca45ad430>,
#               <__main__.Course at 0x22ca45ad280>,
#               <__main__.Course at 0x22ca45ad3d0>,
#               <__main__.Course at 0x22ca45ad460>,
#               <__main__.Course at 0x22ca45ad4f0>,
#               <__main__.Course at 0x22ca45ad520>,
#               <__main__.Course at 0x22ca45ad610>,
#               <__main__.Course at 0x22ca45ad640>,
#               <__main__.Course at 0x22ca45ad670>,
#               <__main__.Course at 0x22ca45ad6a0>,
#               <__main__.Course at 0x22ca45ad6d0>,
#               <__main__.Course at 0x22ca45ad700>,
#               <__main__.Course at 0x22ca45ad730>,
#               <__main__.Course at 0x22ca45ad760>,
#               <__main__.Course at 0x22ca45ad790>,
#               <__main__.Course at 0x22ca45ad7c0>,
#               <__main__.Course at 0x22ca45ad7f0>,
#               <__main__.Course at 0x22ca45ad820>,
#               <__main__.Course at 0x22ca45ad850>,
#               <__main__.Course at 0x22ca45ad880>,
#               <__main__.Course at 0x22ca45ad8b0>,
#               <__main__.Course at 0x22ca45ad8e0>,
#               <__main__.Course at 0x22ca45ad910>,
#               <__main__.Course at 0x22ca45ad940>,
#               <__main__.Course at 0x22ca45ad970>,
#               <__main__.Course at 0x22ca45ad9a0>,
#               <__main__.Course at 0x22ca45ad9d0>,
#               <__main__.Course at 0x22ca45ada00>,
#               <__main__.Course at 0x22ca45ada30>,
#               <__main__.Course at 0x22ca45ada60>,
#               <__main__.Course at 0x22ca45ada90>,
#               <__main__.Course at 0x22ca45adac0>,
#               <__main__.Course at 0x22ca45adaf0>,
#               <__main__.Course at 0x22ca45adb20>,
#               <__main__.Course at 0x22ca45adb50>,
#               <__main__.Course at 0x22ca45adb80>,
#               <__main__.Course at 0x22ca45adbb0>,
#               <__main__.Course at 0x22ca45adbe0>,
#               <__main__.Course at 0x22ca45adc10>,
#               <__main__.Course at 0x22ca45adc40>,
#               <__main__.Course at 0x22ca45adc70>,
#               <__main__.Course at 0x22ca45adca0>,
#               <__main__.Course at 0x22ca45adcd0>,
#               <__main__.Course at 0x22ca45add00>,
#               <__main__.Course at 0x22ca45add30>,
#               <__main__.Course at 0x22ca45add60>,
#               <__main__.Course at 0x22ca45add90>,
#               <__main__.Course at 0x22ca45addc0>,
#               <__main__.Course at 0x22ca45addf0>,
#               <__main__.Course at 0x22ca45ade20>,
#               <__main__.Course at 0x22ca45ade50>,
#               <__main__.Course at 0x22ca45ade80>,
#               <__main__.Course at 0x22ca45adeb0>,
#               <__main__.Course at 0x22ca45adfd0>,
#               <__main__.Course at 0x22ca45adfa0>,
#               <__main__.Course at 0x22ca45adf70>,
#               <__main__.Course at 0x22ca45adf40>,
#               <__main__.Course at 0x22ca45adee0>,
#               <__main__.Course at 0x22ca45adf10>,
#               <__main__.Course at 0x22ca45cc070>,
#               <__main__.Course at 0x22ca45cc040>,
#               <__main__.Course at 0x22ca45cc1c0>,
#               <__main__.Course at 0x22ca45cc190>,
#               <__main__.Course at 0x22ca45cc100>,
#               <__main__.Course at 0x22ca45cc130>,
#               <__main__.Course at 0x22ca45cc160>,
#               <__main__.Course at 0x22ca45cc0d0>,
#               <__main__.Course at 0x22ca45cc0a0>,
#               <__main__.Course at 0x22ca45cc1f0>,
#               <__main__.Course at 0x22ca45cc220>,
#               <__main__.Course at 0x22ca45cc250>,
#               <__main__.Course at 0x22ca45cc280>,
#               <__main__.Course at 0x22ca45cc2b0>,
#               <__main__.Course at 0x22ca45cc2e0>,
#               <__main__.Course at 0x22ca45cc310>,
#               <__main__.Course at 0x22ca45cc340>,
#               <__main__.Course at 0x22ca45cc370>,
#               <__main__.Course at 0x22ca45cc3a0>,
#               <__main__.Course at 0x22ca45cc3d0>,
#               <__main__.Course at 0x22ca45cc400>,
#               <__main__.Course at 0x22ca45cc430>,
#               <__main__.Course at 0x22ca45cc460>,
#               <__main__.Course at 0x22ca45cc490>,
#               <__main__.Course at 0x22ca45cc4c0>,
#               <__main__.Course at 0x22ca45cc4f0>,
#               <__main__.Course at 0x22ca45cc520>,
#               <__main__.Course at 0x22ca45cc550>],
#              1: [<__main__.Course at 0x22ca2f1cee0>,
#               <__main__.Course at 0x22ca2f1cc70>,
#               <__main__.Course at 0x22ca2f1ce80>,
#               <__main__.Course at 0x22ca2ea9fa0>,
#               <__main__.Course at 0x22ca2ec4400>,
#               <__main__.Course at 0x22ca2e5b7c0>,
#               <__main__.Course at 0x22ca2f391f0>,
#               <__main__.Course at 0x22ca2f39a30>,
#               <__main__.Course at 0x22ca2f39fa0>,
#               <__main__.Course at 0x22ca2f39e50>,
#               <__main__.Course at 0x22ca2f39c70>,
#               <__main__.Course at 0x22ca2f397c0>,
#               <__main__.Course at 0x22ca2f39fd0>,
#               <__main__.Course at 0x22ca2d1fc40>,
#               <__main__.Course at 0x22ca2d1f040>,
#               <__main__.Course at 0x22ca2ee05b0>,
#               <__main__.Course at 0x22ca2d1fe20>,
#               <__main__.Course at 0x22ca2d54a30>,
#               <__main__.Course at 0x22ca2d549d0>,
#               <__main__.Course at 0x22ca2d54400>,
#               <__main__.Course at 0x22ca2d54940>,
#               <__main__.Course at 0x22ca2ce9670>,
#               <__main__.Course at 0x22ca2ce9400>,
#               <__main__.Course at 0x22ca2ce9430>,
#               <__main__.Course at 0x22ca2ce9130>,
#               <__main__.Course at 0x22ca2d39b20>,
#               <__main__.Course at 0x22ca2d39af0>,
#               <__main__.Course at 0x22ca3f6ae50>,
#               <__main__.Course at 0x22ca3f6a4c0>,
#               <__main__.Course at 0x22ca3f6a1f0>,
#               <__main__.Course at 0x22ca3fbb640>,
#               <__main__.Course at 0x22ca433b760>,
#               <__main__.Course at 0x22ca433bc40>,
#               <__main__.Course at 0x22ca2ea9e50>,
#               <__main__.Course at 0x22ca2f68610>,
#               <__main__.Course at 0x22ca2f68cd0>,
#               <__main__.Course at 0x22ca2f68bb0>,
#               <__main__.Course at 0x22ca2cce2b0>,
#               <__main__.Course at 0x22ca2cce460>,
#               <__main__.Course at 0x22ca2cce190>,
#               <__main__.Course at 0x22cd13230a0>,
#               <__main__.Course at 0x22cd1323970>,
#               <__main__.Course at 0x22ca44db2e0>,
#               <__main__.Course at 0x22ca44db340>,
#               <__main__.Course at 0x22ca44db370>,
#               <__main__.Course at 0x22ca44db430>,
#               <__main__.Course at 0x22ca44db6d0>,
#               <__main__.Course at 0x22ca44db700>,
#               <__main__.Course at 0x22ca44dbbe0>,
#               <__main__.Course at 0x22ca44dbd30>,
#               <__main__.Course at 0x22ca44dbeb0>,
#               <__main__.Course at 0x22ca44dbe80>,
#               <__main__.Course at 0x22ca44dbee0>,
#               <__main__.Course at 0x22ca44e3220>,
#               <__main__.Course at 0x22ca44e3520>,
#               <__main__.Course at 0x22ca44e36a0>,
#               <__main__.Course at 0x22ca44e3790>,
#               <__main__.Course at 0x22ca44e3b80>,
#               <__main__.Course at 0x22ca439b370>,
#               <__main__.Course at 0x22ca439b460>,
#               <__main__.Course at 0x22ca439b670>,
#               <__main__.Course at 0x22ca439b790>,
#               <__main__.Course at 0x22ca439b7c0>,
#               <__main__.Course at 0x22ca439b6d0>,
#               <__main__.Course at 0x22ca439b760>,
#               <__main__.Course at 0x22ca439b9a0>,
#               <__main__.Course at 0x22ca439bbb0>,
#               <__main__.Course at 0x22ca439bca0>,
#               <__main__.Course at 0x22ca43b7040>,
#               <__main__.Course at 0x22ca43b72e0>,
#               <__main__.Course at 0x22ca43b74c0>,
#               <__main__.Course at 0x22ca43b73a0>,
#               <__main__.Course at 0x22ca43b77f0>,
#               <__main__.Course at 0x22ca43b7730>,
#               <__main__.Course at 0x22ca43b7ee0>,
#               <__main__.Course at 0x22ca43e9910>,
#               <__main__.Course at 0x22ca43e9fd0>,
#               <__main__.Course at 0x22ca4403160>,
#               <__main__.Course at 0x22ca44032b0>,
#               <__main__.Course at 0x22ca4403310>,
#               <__main__.Course at 0x22ca4403040>,
#               <__main__.Course at 0x22ca4403340>,
#               <__main__.Course at 0x22ca4403520>,
#               <__main__.Course at 0x22ca4403970>,
#               <__main__.Course at 0x22ca441e460>,
#               <__main__.Course at 0x22ca441e700>,
#               <__main__.Course at 0x22ca441e4f0>,
#               <__main__.Course at 0x22ca441ea00>,
#               <__main__.Course at 0x22ca441ea30>,
#               <__main__.Course at 0x22ca441ea60>,
#               <__main__.Course at 0x22ca441eac0>,
#               <__main__.Course at 0x22ca441ed00>,
#               <__main__.Course at 0x22ca441ed60>,
#               <__main__.Course at 0x22ca443b1c0>,
#               <__main__.Course at 0x22ca443b490>,
#               <__main__.Course at 0x22ca443b370>,
#               <__main__.Course at 0x22ca443b7f0>,
#               <__main__.Course at 0x22ca443b8b0>,
#               <__main__.Course at 0x22ca443baf0>,
#               <__main__.Course at 0x22ca443ba00>,
#               <__main__.Course at 0x22ca443bf10>,
#               <__main__.Course at 0x22ca443bc70>,
#               <__main__.Course at 0x22ca443bbe0>,
#               <__main__.Course at 0x22ca443be50>,
#               <__main__.Course at 0x22ca44561c0>,
#               <__main__.Course at 0x22ca4456400>,
#               <__main__.Course at 0x22ca4456490>,
#               <__main__.Course at 0x22ca4456520>,
#               <__main__.Course at 0x22ca4456820>,
#               <__main__.Course at 0x22ca4471220>,
#               <__main__.Course at 0x22ca4471520>,
#               <__main__.Course at 0x22ca4471550>,
#               <__main__.Course at 0x22ca4471730>,
#               <__main__.Course at 0x22ca44718b0>,
#               <__main__.Course at 0x22ca4471910>,
#               <__main__.Course at 0x22ca4471c70>,
#               <__main__.Course at 0x22ca44719d0>,
#               <__main__.Course at 0x22ca4471c10>,
#               <__main__.Course at 0x22ca44f0070>,
#               <__main__.Course at 0x22ca44f02e0>,
#               <__main__.Course at 0x22ca44f03a0>,
#               <__main__.Course at 0x22ca44f0430>,
#               <__main__.Course at 0x22ca44f0310>,
#               <__main__.Course at 0x22ca44f0550>,
#               <__main__.Course at 0x22ca44f0580>,
#               <__main__.Course at 0x22ca44f05b0>,
#               <__main__.Course at 0x22ca44f0610>,
#               <__main__.Course at 0x22ca44f09d0>,
#               <__main__.Course at 0x22ca44f0e80>,
#               <__main__.Course at 0x22ca44f0fa0>,
#               <__main__.Course at 0x22ca450d1f0>,
#               <__main__.Course at 0x22ca450d3a0>,
#               <__main__.Course at 0x22ca450d520>,
#               <__main__.Course at 0x22ca450d310>,
#               <__main__.Course at 0x22ca450d4c0>,
#               <__main__.Course at 0x22ca450d5e0>,
#               <__main__.Course at 0x22ca450d550>,
#               <__main__.Course at 0x22ca450d6d0>,
#               <__main__.Course at 0x22ca450d700>,
#               <__main__.Course at 0x22ca450d7f0>,
#               <__main__.Course at 0x22ca450d910>,
#               <__main__.Course at 0x22ca450de20>,
#               <__main__.Course at 0x22ca4529190>,
#               <__main__.Course at 0x22ca45297f0>,
#               <__main__.Course at 0x22ca45298e0>,
#               <__main__.Course at 0x22ca4529670>,
#               <__main__.Course at 0x22ca4529610>,
#               <__main__.Course at 0x22ca4529a30>,
#               <__main__.Course at 0x22ca4529640>,
#               <__main__.Course at 0x22ca4529cd0>,
#               <__main__.Course at 0x22ca4529e50>,
#               <__main__.Course at 0x22ca4529f10>,
#               <__main__.Course at 0x22ca4542340>,
#               <__main__.Course at 0x22ca4542370>,
#               <__main__.Course at 0x22ca45423a0>,
#               <__main__.Course at 0x22ca45423d0>,
#               <__main__.Course at 0x22ca4542460>,
#               <__main__.Course at 0x22ca45424f0>,
#               <__main__.Course at 0x22ca4542820>,
#               <__main__.Course at 0x22ca455f100>,
#               <__main__.Course at 0x22ca455f160>,
#               <__main__.Course at 0x22ca455f1f0>,
#               <__main__.Course at 0x22ca455f4c0>,
#               <__main__.Course at 0x22ca455f550>,
#               <__main__.Course at 0x22ca455f640>,
#               <__main__.Course at 0x22ca455f700>,
#               <__main__.Course at 0x22ca455f7f0>,
#               <__main__.Course at 0x22ca455f910>,
#               <__main__.Course at 0x22ca455fac0>,
#               <__main__.Course at 0x22ca455faf0>,
#               <__main__.Course at 0x22ca455fa60>,
#               <__main__.Course at 0x22ca455fbb0>,
#               <__main__.Course at 0x22ca455fcd0>,
#               <__main__.Course at 0x22ca455fc70>,
#               <__main__.Course at 0x22ca455feb0>,
#               <__main__.Course at 0x22ca457c5b0>,
#               <__main__.Course at 0x22ca457c6d0>,
#               <__main__.Course at 0x22ca457c550>,
#               <__main__.Course at 0x22ca457c790>,
#               <__main__.Course at 0x22ca457cb80>,
#               <__main__.Course at 0x22ca457cbb0>,
#               <__main__.Course at 0x22ca457cd00>,
#               <__main__.Course at 0x22ca457cd90>,
#               <__main__.Course at 0x22ca457cf70>,
#               <__main__.Course at 0x22ca4594160>,
#               <__main__.Course at 0x22ca45945e0>,
#               <__main__.Course at 0x22ca45947f0>,
#               <__main__.Course at 0x22ca4594700>,
# ...
#               <__main__.Course at 0x22ca45ad130>,
#               <__main__.Course at 0x22ca45ad220>,
#               <__main__.Course at 0x22ca45ad4c0>],
#              4: [<__main__.Course at 0x22ca2ea9760>,
#               <__main__.Course at 0x22ca2ea9190>,
#               <__main__.Course at 0x22ca2e5b370>,
#               <__main__.Course at 0x22ca2e5b520>,
#               <__main__.Course at 0x22ca2e41970>,
#               <__main__.Course at 0x22ca2f1cd30>,
#               <__main__.Course at 0x22ca2e71940>,
#               <__main__.Course at 0x22ca2e71c40>,
#               <__main__.Course at 0x22ca2e71340>,
#               <__main__.Course at 0x22ca2e715b0>,
#               <__main__.Course at 0x22ca2e71880>,
#               <__main__.Course at 0x22ca2d1fd60>,
#               <__main__.Course at 0x22ca2d1f3d0>,
#               <__main__.Course at 0x22ca2d1fac0>,
#               <__main__.Course at 0x22ca2d54a00>,
#               <__main__.Course at 0x22ca2d549a0>,
#               <__main__.Course at 0x22ca2f56af0>,
#               <__main__.Course at 0x22ca2f568b0>,
#               <__main__.Course at 0x22ca2ce9a30>,
#               <__main__.Course at 0x22ca2ce9970>,
#               <__main__.Course at 0x22ca2ce9550>,
#               <__main__.Course at 0x22ca2ce9a00>,
#               <__main__.Course at 0x22ca2ce94c0>,
#               <__main__.Course at 0x22ca2d39910>,
#               <__main__.Course at 0x22ca3f6a280>,
#               <__main__.Course at 0x22ca2f68b80>,
#               <__main__.Course at 0x22ca2f68f70>,
#               <__main__.Course at 0x22ca44db520>,
#               <__main__.Course at 0x22ca44db3d0>,
#               <__main__.Course at 0x22ca44db9a0>,
#               <__main__.Course at 0x22ca44dbd00>,
#               <__main__.Course at 0x22ca44e3760>,
#               <__main__.Course at 0x22ca44e3bb0>,
#               <__main__.Course at 0x22ca44e3d90>,
#               <__main__.Course at 0x22ca44e3f40>,
#               <__main__.Course at 0x22ca439b3d0>,
#               <__main__.Course at 0x22ca43b71f0>,
#               <__main__.Course at 0x22ca43b7070>,
#               <__main__.Course at 0x22ca43b7310>,
#               <__main__.Course at 0x22ca43b7610>,
#               <__main__.Course at 0x22ca43b73d0>,
#               <__main__.Course at 0x22ca43b74f0>,
#               <__main__.Course at 0x22ca43b7670>,
#               <__main__.Course at 0x22ca43b7880>,
#               <__main__.Course at 0x22ca43b7790>,
#               <__main__.Course at 0x22ca43b7a00>,
#               <__main__.Course at 0x22ca43b7d00>,
#               <__main__.Course at 0x22ca43b7ca0>,
#               <__main__.Course at 0x22ca43b7e80>,
#               <__main__.Course at 0x22ca43b7e50>,
#               <__main__.Course at 0x22ca43d2190>,
#               <__main__.Course at 0x22ca43d2340>,
#               <__main__.Course at 0x22ca43d23a0>,
#               <__main__.Course at 0x22ca43d2490>,
#               <__main__.Course at 0x22ca43d22e0>,
#               <__main__.Course at 0x22ca43d2430>,
#               <__main__.Course at 0x22ca43d2730>,
#               <__main__.Course at 0x22ca43d2250>,
#               <__main__.Course at 0x22ca43d2df0>,
#               <__main__.Course at 0x22ca43d2e50>,
#               <__main__.Course at 0x22ca43d2c40>,
#               <__main__.Course at 0x22ca43d2ee0>,
#               <__main__.Course at 0x22ca43d2f40>,
#               <__main__.Course at 0x22ca43d2c70>,
#               <__main__.Course at 0x22ca43e90a0>,
#               <__main__.Course at 0x22ca43e9280>,
#               <__main__.Course at 0x22ca43e94f0>,
#               <__main__.Course at 0x22ca43e95b0>,
#               <__main__.Course at 0x22ca43e9610>,
#               <__main__.Course at 0x22ca43e9220>,
#               <__main__.Course at 0x22ca43e97f0>,
#               <__main__.Course at 0x22ca43e9340>,
#               <__main__.Course at 0x22ca43e9970>,
#               <__main__.Course at 0x22ca43e9640>,
#               <__main__.Course at 0x22ca43e9a00>,
#               <__main__.Course at 0x22ca4403460>,
#               <__main__.Course at 0x22ca4403370>,
#               <__main__.Course at 0x22ca44036a0>,
#               <__main__.Course at 0x22ca4403a00>,
#               <__main__.Course at 0x22ca44038b0>,
#               <__main__.Course at 0x22ca4403b20>,
#               <__main__.Course at 0x22ca4403b80>,
#               <__main__.Course at 0x22ca4403910>,
#               <__main__.Course at 0x22ca4403610>,
#               <__main__.Course at 0x22ca44039a0>,
#               <__main__.Course at 0x22ca4403a60>,
#               <__main__.Course at 0x22ca4403e50>,
#               <__main__.Course at 0x22ca441e130>,
#               <__main__.Course at 0x22ca441e310>,
#               <__main__.Course at 0x22ca441e5b0>,
#               <__main__.Course at 0x22ca441e520>,
#               <__main__.Course at 0x22ca443b100>,
#               <__main__.Course at 0x22ca443b040>,
#               <__main__.Course at 0x22ca443b640>,
#               <__main__.Course at 0x22ca443b550>,
#               <__main__.Course at 0x22ca443b970>,
#               <__main__.Course at 0x22ca443b790>,
#               <__main__.Course at 0x22ca443be20>,
#               <__main__.Course at 0x22ca44562e0>,
#               <__main__.Course at 0x22ca4456100>,
#               <__main__.Course at 0x22ca4456460>,
#               <__main__.Course at 0x22ca44565e0>,
#               <__main__.Course at 0x22ca4456790>,
#               <__main__.Course at 0x22ca4456670>,
#               <__main__.Course at 0x22ca4456970>,
#               <__main__.Course at 0x22ca4456af0>,
#               <__main__.Course at 0x22ca4456d30>,
#               <__main__.Course at 0x22ca4456d60>,
#               <__main__.Course at 0x22ca4456df0>,
#               <__main__.Course at 0x22ca4456e20>,
#               <__main__.Course at 0x22ca4456e80>,
#               <__main__.Course at 0x22ca4471040>,
#               <__main__.Course at 0x22ca4471160>,
#               <__main__.Course at 0x22ca44711c0>,
#               <__main__.Course at 0x22ca44711f0>,
#               <__main__.Course at 0x22ca4471400>,
#               <__main__.Course at 0x22ca4471640>,
#               <__main__.Course at 0x22ca44716d0>,
#               <__main__.Course at 0x22ca4471760>,
#               <__main__.Course at 0x22ca4471af0>,
#               <__main__.Course at 0x22ca4471be0>,
#               <__main__.Course at 0x22ca4471a90>,
#               <__main__.Course at 0x22ca4471b20>,
#               <__main__.Course at 0x22ca4471df0>,
#               <__main__.Course at 0x22ca4471e80>,
#               <__main__.Course at 0x22ca4471e50>,
#               <__main__.Course at 0x22ca44f0700>,
#               <__main__.Course at 0x22ca44f0670>,
#               <__main__.Course at 0x22ca44f0ac0>,
#               <__main__.Course at 0x22ca44f0c40>,
#               <__main__.Course at 0x22ca44f0b80>,
#               <__main__.Course at 0x22ca44f0b20>,
#               <__main__.Course at 0x22ca450d340>,
#               <__main__.Course at 0x22ca450df10>,
#               <__main__.Course at 0x22ca4529880>,
#               <__main__.Course at 0x22ca45296a0>,
#               <__main__.Course at 0x22ca45426d0>,
#               <__main__.Course at 0x22ca4542940>,
#               <__main__.Course at 0x22ca4542d90>,
#               <__main__.Course at 0x22ca4542e50>,
#               <__main__.Course at 0x22ca4542e80>,
#               <__main__.Course at 0x22ca455f940>,
#               <__main__.Course at 0x22ca457c400>,
#               <__main__.Course at 0x22ca457c460>,
#               <__main__.Course at 0x22ca457c4c0>,
#               <__main__.Course at 0x22ca457c130>,
#               <__main__.Course at 0x22ca457c160>,
#               <__main__.Course at 0x22ca457c3a0>,
#               <__main__.Course at 0x22ca457c4f0>,
#               <__main__.Course at 0x22ca457c520>,
#               <__main__.Course at 0x22ca457c880>,
#               <__main__.Course at 0x22ca457cc10>,
#               <__main__.Course at 0x22ca45942b0>,
#               <__main__.Course at 0x22ca4594520>,
#               <__main__.Course at 0x22ca45ad190>,
#               <__main__.Course at 0x22ca45ad100>],
#              5: [<__main__.Course at 0x22ca2e5b0a0>,
#               <__main__.Course at 0x22ca2e5b790>,
#               <__main__.Course at 0x22ca2e41c70>,
#               <__main__.Course at 0x22ca2e41e80>,
#               <__main__.Course at 0x22ca2e41880>,
#               <__main__.Course at 0x22ca2e71040>,
#               <__main__.Course at 0x22ca2d54af0>,
#               <__main__.Course at 0x22ca2d54970>,
#               <__main__.Course at 0x22ca2d547f0>,
#               <__main__.Course at 0x22ca2f56670>,
#               <__main__.Course at 0x22ca3f840d0>,
#               <__main__.Course at 0x22ca2d39c10>,
#               <__main__.Course at 0x22ca2d39bb0>,
#               <__main__.Course at 0x22ca3fbb6d0>,
#               <__main__.Course at 0x22ca3fbbd90>,
#               <__main__.Course at 0x22ca2d045e0>,
#               <__main__.Course at 0x22ca2d04b80>,
#               <__main__.Course at 0x22ca2d04160>,
#               <__main__.Course at 0x22ca44db2b0>,
#               <__main__.Course at 0x22ca44db460>,
#               <__main__.Course at 0x22ca44db760>,
#               <__main__.Course at 0x22ca44db7c0>,
#               <__main__.Course at 0x22ca44e30d0>,
#               <__main__.Course at 0x22ca44e3310>,
#               <__main__.Course at 0x22ca43b76d0>,
#               <__main__.Course at 0x22ca43b7700>,
#               <__main__.Course at 0x22ca43d21c0>,
#               <__main__.Course at 0x22ca43d2220>,
#               <__main__.Course at 0x22ca43d2130>,
#               <__main__.Course at 0x22ca43d20d0>,
#               <__main__.Course at 0x22ca43d2550>,
#               <__main__.Course at 0x22ca43d25e0>,
#               <__main__.Course at 0x22ca43d23d0>,
#               <__main__.Course at 0x22ca43d2580>,
#               <__main__.Course at 0x22ca43d2850>,
#               <__main__.Course at 0x22ca43d2970>,
#               <__main__.Course at 0x22ca43d2d00>,
#               <__main__.Course at 0x22ca43e91f0>,
#               <__main__.Course at 0x22ca43e9430>,
#               <__main__.Course at 0x22ca43e96a0>,
#               <__main__.Course at 0x22ca43e92b0>,
#               <__main__.Course at 0x22ca43e93a0>,
#               <__main__.Course at 0x22ca43e9850>,
#               <__main__.Course at 0x22ca43e96d0>,
#               <__main__.Course at 0x22ca43e9700>,
#               <__main__.Course at 0x22ca43e98e0>,
#               <__main__.Course at 0x22ca44034f0>,
#               <__main__.Course at 0x22ca4403700>,
#               <__main__.Course at 0x22ca4403250>,
#               <__main__.Course at 0x22ca441e0a0>,
#               <__main__.Course at 0x22ca441e1f0>,
#               <__main__.Course at 0x22ca441e370>,
#               <__main__.Course at 0x22ca441e4c0>,
#               <__main__.Course at 0x22ca441e6a0>,
#               <__main__.Course at 0x22ca441e670>,
#               <__main__.Course at 0x22ca441ed30>,
#               <__main__.Course at 0x22ca443b4f0>,
#               <__main__.Course at 0x22ca443b9d0>,
#               <__main__.Course at 0x22ca443bb80>,
#               <__main__.Course at 0x22ca443ba60>,
#               <__main__.Course at 0x22ca443ba90>,
#               <__main__.Course at 0x22ca443bee0>,
#               <__main__.Course at 0x22ca44563a0>,
#               <__main__.Course at 0x22ca44566a0>,
#               <__main__.Course at 0x22ca44566d0>,
#               <__main__.Course at 0x22ca44569d0>,
#               <__main__.Course at 0x22ca4456a30>,
#               <__main__.Course at 0x22ca4456c40>,
#               <__main__.Course at 0x22ca4456fa0>,
#               <__main__.Course at 0x22ca4456e50>,
#               <__main__.Course at 0x22ca4471190>,
#               <__main__.Course at 0x22ca44710d0>,
#               <__main__.Course at 0x22ca4471280>,
#               <__main__.Course at 0x22ca44f06d0>,
#               <__main__.Course at 0x22ca44f0b50>,
#               <__main__.Course at 0x22ca4529910>,
#               <__main__.Course at 0x22ca4542790>,
#               <__main__.Course at 0x22ca457c340>,
#               <__main__.Course at 0x22ca457c760>,
#               <__main__.Course at 0x22ca457cdc0>,
#               <__main__.Course at 0x22ca4594070>,
#               <__main__.Course at 0x22ca45942e0>,
#               <__main__.Course at 0x22ca4594250>],
#              6: [<__main__.Course at 0x22ca2d1ff40>,
#               <__main__.Course at 0x22ca2f1c7c0>,
#               <__main__.Course at 0x22ca2d39190>,
#               <__main__.Course at 0x22ca3f6a640>,
#               <__main__.Course at 0x22ca3f6a850>,
#               <__main__.Course at 0x22ca3fbb160>,
#               <__main__.Course at 0x22ca3fbbe20>,
#               <__main__.Course at 0x22ca3fbb550>,
#               <__main__.Course at 0x22ca2d04cd0>,
#               <__main__.Course at 0x22ca2d043a0>,
#               <__main__.Course at 0x22ca2d04af0>,
#               <__main__.Course at 0x22cd13234f0>,
#               <__main__.Course at 0x22ca44db5b0>,
#               <__main__.Course at 0x22ca44db6a0>,
#               <__main__.Course at 0x22ca44db8b0>,
#               <__main__.Course at 0x22ca44dba00>,
#               <__main__.Course at 0x22ca44db850>,
#               <__main__.Course at 0x22ca44dbb50>,
#               <__main__.Course at 0x22ca44dbaf0>,
#               <__main__.Course at 0x22ca44dbe20>,
#               <__main__.Course at 0x22ca44e3160>,
#               <__main__.Course at 0x22ca43b7bb0>,
#               <__main__.Course at 0x22ca43d2040>,
#               <__main__.Course at 0x22ca43d20a0>,
#               <__main__.Course at 0x22ca43d27c0>,
#               <__main__.Course at 0x22ca43d28b0>,
#               <__main__.Course at 0x22ca43e9160>,
#               <__main__.Course at 0x22ca43e9ac0>,
#               <__main__.Course at 0x22ca4403790>,
#               <__main__.Course at 0x22ca4403880>,
#               <__main__.Course at 0x22ca4403be0>,
#               <__main__.Course at 0x22ca4403ee0>,
#               <__main__.Course at 0x22ca441e8b0>,
#               <__main__.Course at 0x22ca441e850>,
#               <__main__.Course at 0x22ca441eaf0>,
#               <__main__.Course at 0x22ca441eca0>,
#               <__main__.Course at 0x22ca443b0a0>,
#               <__main__.Course at 0x22ca4456ac0>,
#               <__main__.Course at 0x22ca4456f10>,
#               <__main__.Course at 0x22ca4471100>,
#               <__main__.Course at 0x22ca4471130>,
#               <__main__.Course at 0x22ca44710a0>,
#               <__main__.Course at 0x22ca4471070>,
#               <__main__.Course at 0x22ca4471eb0>,
#               <__main__.Course at 0x22ca44f0730>,
#               <__main__.Course at 0x22ca44f0d60>,
#               <__main__.Course at 0x22ca4529940>,
#               <__main__.Course at 0x22ca4542610>,
#               <__main__.Course at 0x22ca4542550>,
#               <__main__.Course at 0x22ca45428e0>,
#               <__main__.Course at 0x22ca4542760>,
#               <__main__.Course at 0x22ca4594130>],
#              7: [<__main__.Course at 0x22ca2d39ca0>,
#               <__main__.Course at 0x22ca3fbbd00>,
#               <__main__.Course at 0x22ca3fbbf70>,
#               <__main__.Course at 0x22ca3fbb190>,
#               <__main__.Course at 0x22ca2d04d00>,
#               <__main__.Course at 0x22ca2d04640>,
#               <__main__.Course at 0x22ca2d04490>,
#               <__main__.Course at 0x22ca2d040a0>,
#               <__main__.Course at 0x22ca44e3070>,
#               <__main__.Course at 0x22ca4403550>,
#               <__main__.Course at 0x22ca441e400>,
#               <__main__.Course at 0x22ca441eb50>,
#               <__main__.Course at 0x22ca441edc0>,
#               <__main__.Course at 0x22ca4471fa0>,
#               <__main__.Course at 0x22ca450d460>,
#               <__main__.Course at 0x22ca4529520>,
#               <__main__.Course at 0x22ca4542250>],
#              8: [<__main__.Course at 0x22ca2d39f40>,
#               <__main__.Course at 0x22ca2d04400>,
#               <__main__.Course at 0x22ca441e280>,
#               <__main__.Course at 0x22ca441e490>,
#               <__main__.Course at 0x22ca441ec70>,
#               <__main__.Course at 0x22ca45425e0>,
#               <__main__.Course at 0x22ca4594040>],
#              9: [<__main__.Course at 0x22ca441efa0>]})
